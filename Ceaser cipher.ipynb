# %% [markdown]
# **Gunda Ramahanisha**
#
# **E19CSE237**
#
# **EB11**

# %%
class Ceasar():
  def encrypt(word,key):
   result = ""
   word=word.lower()
   for i in range(len(word)):
      char = word[i]
      result += chr((ord(char) + key))
   return result

   def decrypt(result,key):
    ans=""
    for i in range(len(result)):
       char = result[i]
       ans += chr((ord(char) - key))
    return ans

print("Plain text: ", end="")
word = input()
print("Key: ",end="")
key = int(input())

print("Cipher Text: " + encrypt(word,key))
ans = encrypt(word,key)
print("Plain Text: " + decrypt(result,key))
# Out:
# Plain text: HELLO
# Key: 3
# Cipher Text: khoor
# Plain Text: hello
